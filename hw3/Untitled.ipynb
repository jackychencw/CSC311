# %%
# !pip2 install request
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Collecting request
#   Using cached https://files.pythonhosted.org/packages/f1/27/7cbde262d854aedf217061a97020d66a63163c5c04e0ec02ff98c5d8f44e/request-2019.4.13.tar.gz
# Collecting get (from request)
#   Using cached https://files.pythonhosted.org/packages/3f/ef/bb46f77f7220ac1b7edba0c76d810c89fddb24ddd8c08f337b9b4a618db7/get-2019.4.13.tar.gz
# Collecting post (from request)
#   Using cached https://files.pythonhosted.org/packages/0f/05/bd79da5849ea6a92485ed7029ef97b1b75e55c26bc0ed3a7ec769af666f3/post-2019.4.13.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/site-packages (from request) (41.0.1)
# Collecting query_string (from get->request)
#   Using cached https://files.pythonhosted.org/packages/12/3c/412a45daf5bea9b1d06d7de41787ec4168001dfa418db7ec8723356b119f/query-string-2019.4.13.tar.gz
# Collecting public (from query_string->get->request)
#   Using cached https://files.pythonhosted.org/packages/54/4d/b40004cc6c07665e48af22cfe1e631f219bf4282e15fa76a5b6364f6885c/public-2019.4.13.tar.gz
# Building wheels for collected packages: request, get, post, query-string, public
#   Building wheel for request (setup.py) ... done
#   Stored in directory: /Users/jackychencw/Library/Caches/pip/wheels/30/84/5f/484cfba678967ef58c16fce6890925d5c7172622f20111fbfd
#   Building wheel for get (setup.py) ... done
#   Stored in directory: /Users/jackychencw/Library/Caches/pip/wheels/c1/e3/c1/d02c8c58538853e4c9b78cadb74f6d5c5c370b48a69a7271aa
#   Building wheel for post (setup.py) ... done
#   Stored in directory: /Users/jackychencw/Library/Caches/pip/wheels/c3/c3/24/b5c132b537ab380c02d69e6bd4dec1f5db56b5fe19030473d7
#   Building wheel for query-string (setup.py) ... done
#   Stored in directory: /Users/jackychencw/Library/Caches/pip/wheels/d6/a4/78/01b20a9dc224dcc009fab669f7f27b943b8889c5150bd68d8a
#   Building wheel for public (setup.py) ... done
#   Stored in directory: /Users/jackychencw/Library/Caches/pip/wheels/23/7c/6e/f5b4e09d6596c8b8802b347e48f149031e2363368048f1347a
# Successfully built request get post query-string public
# Installing collected packages: public, query-string, get, post, request
# Successfully installed get-2019.4.13 post-2019.4.13 public-2019.4.13 query-string-2019.4.13 request-2019.4.13

# %%
from __future__ import absolute_import
from __future__ import print_function
from urllib.request import urlretrieve
import matplotlib.image
import matplotlib.pyplot as plt
import array
import struct
import gzip
import os
import numpy as np
from future.standard_library import install_aliases
install_aliases()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-1c572b7055e2> in <module>()
#       1 from __future__ import absolute_import
#       2 from __future__ import print_function
# ----> 3 from urllib.request import urlretrieve
#       4 import matplotlib.image
#       5 import matplotlib.pyplot as plt
#
# ImportError: No module named request
